# %% [markdown]
# ## ResNet50 + GAP + DenseLayer 모델 생성

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

import copy
import cv2
from PIL import Image

tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# 데이터 준비
(ds_train, ds_test), ds_info = tfds.load(
    'stanford_dogs',
    split=['train', 'test'],
    shuffle_files=True,
    with_info=True,
)

# %%
# 다운로드한 데이터 확인
tfds.show_examples(ds_train, ds_info)

# %%
# 레이어 구성
num_classes = ds_info.features["label"].num_classes
base_model = keras.applications.resnet50.ResNet50(
    include_top=False,    # Imagenet 분류기  fully connected layer 제거
    weights='imagenet',
    input_shape=(224, 224, 3),
    pooling='avg',      # GAP를 적용  
)
x = base_model.output
# CAM을 위한 softmax dense layer 추가 
preds = keras.layers.Dense(num_classes, activation='softmax')(x)
cam_model = keras.Model(inputs=base_model.input, outputs=preds)
# Out:
# ...
# 94781440/94765736 [==============================] - 0s 0us/step

# %%
# 모델 확인
cam_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# ...

# %%
# 데이터 전처리 
def normalize_and_resize_img(input):
    # Normalizes images: `uint8` -> `float32`
    image = tf.image.resize(input['image'], [224, 224])
    input['image'] = tf.cast(image, tf.float32) / 255.
    return input['image'], input['label']

def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=2
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# 데이터셋에 전처리와 배치처리를 적용합니다.
ds_train_norm = apply_normalize_on_dataset(ds_train)
ds_val_norm = apply_normalize_on_dataset(ds_test)

# 구성된 배치의 모양을 확인 
for input in ds_train_norm.take(1):
    image, label = input
    print(image.shape)
    print(label.shape)
# Out:
# (16, 224, 224, 3)
# (16,)

# %%
# 모델 학습
cam_model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.01),
    metrics=['accuracy'],
)
history_cam_model = cam_model.fit(
    ds_train_norm,
    steps_per_epoch=int(ds_info.splits['train'].num_examples/16),
    validation_steps=int(ds_info.splits['test'].num_examples/16),
    epochs=2,
    validation_data=ds_val_norm,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/2
# 750/750 [==============================] - 211s 212ms/step - loss: 2.2126 - accuracy: 0.4404 - val_loss: 3.5393 - val_accuracy: 0.1847
# Epoch 2/2
# 750/750 [==============================] - 167s 223ms/step - loss: 0.7183 - accuracy: 0.8060 - val_loss: 1.2317 - val_accuracy: 0.6495

# %%
# 학습된 모델 저장
cam_model_path = '/aiffel/class_activation_map'
cam_model.save(cam_model_path)
# Out:
# INFO:tensorflow:Assets written to: /aiffel/class_activation_map/assets
# INFO:tensorflow:Assets written to: /aiffel/class_activation_map/assets
# /opt/conda/lib/python3.9/site-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
# 저장한 모델 가져오기 
import os
cam_model_path = os.getenv('HOME')+'/aiffel/class_activation_map/cam_model.h5'
cam_model = tf.keras.models.load_model(cam_model_path)

# %%
# 데이터 테스트시 편하게 가져오기위해서 함수생성
def get_one(ds):
    ds = ds.take(1)
    sample_data = list(ds.as_numpy_iterator())
    bbox = sample_data[0]['objects']['bbox']
    image = sample_data[0]['image']
    label = sample_data[0]['label']
    print(label)
    return sample_data[0]

# 정상적으로 가져오는지 테스트
item = get_one(ds_test)
plt.imshow(item['image'])
plt.show()
# Out:
# 23

# %% [markdown]
# ## CAM 구현하기

# %%
def generate_cam(model, item):
    item = copy.deepcopy(item)
    width = item['image'].shape[1]
    height = item['image'].shape[0]
    
    img_tensor, class_idx = normalize_and_resize_img(item)
    
    # 학습한 모델에서 원하는 Layer의 output을 얻기 위해서 모델의 input과 output을 새롭게 정의해줍니다.
    cam_model = tf.keras.models.Model([model.inputs], [model.layers[-3].output, model.output])
    conv_outputs, predictions = cam_model(tf.expand_dims(img_tensor, 0))
    conv_outputs = conv_outputs[0, :, :, :]
    
    # 모델의 weight activation은 마지막 layer에 있습니다.
    class_weights = model.layers[-1].get_weights()[0] 
    
    cam_image = np.zeros(dtype=np.float32, shape=conv_outputs.shape[0:2])
    for i, w in enumerate(class_weights[:, class_idx]):
        # conv_outputs의 i번째 채널과 i번째 weight를 곱해서 누적하면 활성화된 정도가 나타날 겁니다.
        cam_image += w * conv_outputs[:, :, i]

    cam_image /= np.max(cam_image) # activation score를 normalize합니다.
    cam_image = cam_image.numpy()
    cam_image = cv2.resize(cam_image, (width, height)) # 원래 이미지의 크기로 resize합니다.
    return cam_image

# %%
# CAM 이미지 확인
plt.imshow(item['image'])
plt.show()

cam_image = generate_cam(cam_model, item)
plt.imshow(cam_image)
plt.show()

# %%
def visualize_cam_on_image(src1, src2, alpha=0.5):
    beta = (1.0 - alpha)
    merged_image = cv2.addWeighted(src1, alpha, src2, beta, 0.0)
    return merged_image

origin_image = item['image'].astype(np.uint8)
cam_image_3channel = np.stack([cam_image*255]*3, axis=-1).astype(np.uint8)

blended_image = visualize_cam_on_image(cam_image_3channel, origin_image)
plt.imshow(blended_image)
plt.show()

# %% [markdown]
# ## Grad-CAM 구현하기

# %%
def generate_grad_cam(model, activation_layer, item):
    item = copy.deepcopy(item)
    width = item['image'].shape[1]
    height = item['image'].shape[0]
    img_tensor, class_idx = normalize_and_resize_img(item)
    
    # Grad cam에서도 cam과 같이 특정 레이어의 output을 필요로 하므로 모델의 input과 output을 새롭게 정의합니다.
    # 이때 원하는 레이어가 다를 수 있으니 해당 레이어의 이름으로 찾은 후 output으로 추가합니다.
    grad_model = tf.keras.models.Model([model.inputs], [model.get_layer(activation_layer).output, model.output])
    
    # Gradient를 얻기 위해 tape를 사용합니다.
    with tf.GradientTape() as tape:
        conv_output, pred = grad_model(tf.expand_dims(img_tensor, 0))
    
        loss = pred[:, class_idx] # 원하는 class(여기서는 정답으로 활용) 예측값을 얻습니다.
        output = conv_output[0] # 원하는 layer의 output을 얻습니다.
        grad_val = tape.gradient(loss, conv_output)[0] # 예측값에 따른 Layer의 gradient를 얻습니다.

    weights = np.mean(grad_val, axis=(0, 1)) # gradient의 GAP으로 weight를 구합니다.
    grad_cam_image = np.zeros(dtype=np.float32, shape=conv_output.shape[0:2])
    for k, w in enumerate(weights):
        # output의 k번째 채널과 k번째 weight를 곱하고 누적해서 class activation map을 얻습니다.
        grad_cam_image += w * output[:, :, k]
        
    grad_cam_image = tf.math.maximum(0, grad_cam_image)
    grad_cam_image /= np.max(grad_cam_image)
    grad_cam_image = grad_cam_image.numpy()
    grad_cam_image = cv2.resize(grad_cam_image, (width, height))
    return grad_cam_image

# %%
# grad cam 확인 
plt.imshow(item['image'])
plt.show()

grad_cam_image = generate_grad_cam(cam_model, 'conv5_block3_out', item)
plt.imshow(grad_cam_image)
plt.show()

grad_cam_image = generate_grad_cam(cam_model, 'conv4_block3_out', item)
plt.imshow(grad_cam_image)
plt.show()

grad_cam_image = generate_grad_cam(cam_model, 'conv3_block3_out', item)
plt.imshow(grad_cam_image)
plt.show()

# %% [markdown]
# ## 바운딩 박스 구하기

# %%
def get_bbox(cam_image, score_thresh=0.05):
    low_indicies = cam_image <= score_thresh
    cam_image[low_indicies] = 0
    cam_image = (cam_image*255).astype(np.uint8)
    
    contours,_ = cv2.findContours(cam_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cnt = contours[0]
    rotated_rect = cv2.minAreaRect(cnt)
    rect = cv2.boxPoints(rotated_rect)
    rect = np.int0(rect)
    return rect

# %%
rect = get_bbox(cam_image)
image = copy.deepcopy(item['image'])
image = cv2.drawContours(image, [rect], 0, (0,0,255), 2)
plt.imshow(image)
plt.show()

# %% [markdown]
# ## IoU 구하기

# %%
# rect의 좌표는 (x, y) 형태로, bbox는 (y_min, x_min, y_max, x_max)의 normalized 형태로 주어집니다. 
def rect_to_minmax(rect, image):
    bbox = [
        rect[:,1].min()/float(image.shape[0]),  #bounding box의 y_min
        rect[:,0].min()/float(image.shape[1]),  #bounding box의 x_min
        rect[:,1].max()/float(image.shape[0]), #bounding box의 y_max
        rect[:,0].max()/float(image.shape[1]) #bounding box의 x_max
    ]
    return bbox

# %%
def get_iou(boxA, boxB):
    y_min = max(boxA[0], boxB[0])
    x_min= max(boxA[1], boxB[1])
    y_max = min(boxA[2], boxB[2])
    x_max = min(boxA[3], boxB[3])
    
    interArea = max(0, x_max - x_min) * max(0, y_max - y_min)
    boxAArea = (boxA[2] - boxA[0]) * (boxA[3] - boxA[1])
    boxBArea = (boxB[2] - boxB[0]) * (boxB[3] - boxB[1])
    iou = interArea / float(boxAArea + boxBArea - interArea)

    return iou

# %%
pred_bbox = rect_to_minmax(rect, item['image'])
get_iou(pred_bbox, item['objects']['bbox'][0])
# Out:
# 0.5165352741867694

# %% [markdown]
# ## 테스트 및 확인

# %%
# 테스트 편하라고 plt 함수 생성
import matplotlib
import math
"""
image_data = [
    {'title':'얼굴 전체(눈코입)이 보여야 인식함', 'image':'face_multi.jpeg'}, 
    {'title':'다보이면 여러개로 인식', 'image':'face_multi02.jpeg'},
]
"""
def show_plt(image_data, figsize = (15.0, 8.0)) :
    plt.rcParams['figure.figsize'] = figsize
    matplotlib.rcParams['axes.unicode_minus'] =False
    
    col = 3
    row = math.ceil(len(image_data)/col)
    for i, image in enumerate(image_data): 
        i += 1
        title = image['title']
        plt.subplot(row, col, i) 
        plt.title(title)

        #image = cv2.cvtColor(cv2.imread(join(img_dir,image['file_name'])), cv2.COLOR_BGR2RGB)
        #fill_rectangle(image, get_dlib_rects(image), 2)
        plt.imshow(image['image'])
    plt.show()

# %% [markdown]
# ### CAM , GRAD_CAM

# %%
test01_image_data = []

test01_image_data.append({
    'title': 'origin',
    'image': item['image'],
})
test01_image_data.append({
    'title': 'cam',
    'image': generate_cam(cam_model, item),
})
test01_image_data.append({
    'title': 'grad_cam conv5_block3_out',
    'image': generate_grad_cam(cam_model, 'conv5_block3_out', item),
})
show_plt(test01_image_data)

# %% [markdown]
# ### CAM , GRAD_CAM 바운딩 박스 구하기

# %%
test02_image_data = []

cam_image = cv2.drawContours(copy.deepcopy(item['image']), [get_bbox(cam_image)], 0, (0,0,255), 2)
grad_cam_image = cv2.drawContours(copy.deepcopy(item['image']), [get_bbox(grad_cam_image)], 0, (0,0,255), 2)

test02_image_data.append({
    'title': 'origin',
    'image': item['image'],
})
test02_image_data.append({
    'title': 'cam',
    'image': cam_image,
})
test02_image_data.append({
    'title': 'grad_cam conv5_block3_out',
    'image': grad_cam_image,
})
show_plt(test02_image_data)

# %%
# 이미지마다 정상적으로 안그려지는게있다고해서 테스트해봄
item = get_one(ds_test)
# Out:
# 100

# %%
def test_show_rect_box(image):
    sample_image = []
    
    cam_image = generate_cam(cam_model, item)
    grad_cam_image = generate_grad_cam(cam_model, 'conv5_block3_out', item)
    
    sample_image.append({
        'title': 'origin',
        'image': item['image'],
    })
    sample_image.append({
        'title': 'cam',
        'image': cam_image,
    })
    sample_image.append({
        'title': 'grad_cam conv5_block3_out',
        'image': grad_cam_image,
    })

    cam_image = cv2.drawContours(copy.deepcopy(item['image']), [get_bbox(cam_image)], 0, (0,0,255), 2)
    grad_cam_image = cv2.drawContours(copy.deepcopy(item['image']), [get_bbox(grad_cam_image)], 0, (0,0,255), 2)

    sample_image.append({
        'title': 'origin',
        'image': item['image'],
    })
    sample_image.append({
        'title': 'cam',
        'image': cam_image,
    })
    sample_image.append({
        'title': 'grad_cam conv5_block3_out',
        'image': grad_cam_image,
    })
    show_plt(sample_image)

test_show_rect_box(item)

# %%
# grad_cam 라운딩박스 영역 이상하게 잡힌거 확인 뭐가문제인지 테스트좀해봄 
# 박스영역 문제니까 박스부터 뜯어봄
test_image = item
test_grad_cam_image = generate_grad_cam(cam_model, 'conv5_block3_out', test_image)
def get_bbox2(cam_image, score_thresh=0.05):
    low_indicies = cam_image <= score_thresh
    cam_image[low_indicies] = 0
    cam_image = (cam_image*255).astype(np.uint8)
    
    contours,_ = cv2.findContours(cam_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    #print(contours)
    cnt = contours[1]
    rotated_rect = cv2.minAreaRect(cnt)
    rect = cv2.boxPoints(rotated_rect)
    rect = np.int0(rect)
    return rect

test_grad_cam_image = cv2.drawContours(copy.deepcopy(item['image']), [get_bbox2(test_grad_cam_image)], 0, (0,0,255), 2)

plt.imshow(test_grad_cam_image)
plt.show()

# %%
# findContours 에서 왠지 여러개의 박스를 찾을것같아서 contours 변경해보니까 이론이맞는것같음 제대로 확인해봄
def get_bbox3(cam_image, score_thresh=0.05):
    low_indicies = cam_image <= score_thresh
    cam_image[low_indicies] = 0
    cam_image = (cam_image*255).astype(np.uint8)
    
    contours,_ = cv2.findContours(cam_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    rects = []
    ## 이미지마다 찾아지는 영역 개수가 다름 
    for index in range(len(contours)):
        cnt = contours[index]
        rotated_rect = cv2.minAreaRect(cnt)
        rect = cv2.boxPoints(rotated_rect)
        rects.append(np.int0(rect))
    return rects
box_rects = get_bbox3(test_grad_cam_image)

# 검색된 영역별 grad_cam 확인
sample_image4 = []
for i, rect in enumerate(box_rects):
    sample_image4.append({
        'title': f'grad_cam {i}',
        'image': cv2.drawContours(copy.deepcopy(test_image['image']), [rect], 0, (0,0,255), 2),
    })
show_plt(sample_image4)

# %% [markdown]
# 원인확인 완료 다음으로

# %% [markdown]
# ### CAM , GRAD_CAM IoU 구하기

# %%
iou_cam_image = generate_cam(cam_model, item)
pred_bbox = rect_to_minmax(get_bbox(cam_image), item['image'])
print("CAM : ",get_iou(pred_bbox, item['objects']['bbox'][0]))

iou_grad_cam_image = generate_grad_cam(cam_model, 'conv5_block3_out', item)
pred_bbox = rect_to_minmax(get_bbox(iou_grad_cam_image), item['image'])
print("GRAD_CAM :",get_iou(pred_bbox, item['objects']['bbox'][0]))

def get_bbox2(cam_image, score_thresh=0.05):
    low_indicies = cam_image <= score_thresh
    cam_image[low_indicies] = 0
    cam_image = (cam_image*255).astype(np.uint8)
    
    contours,_ = cv2.findContours(cam_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    #print(contours)
    cnt = contours[1]
    rotated_rect = cv2.minAreaRect(cnt)
    rect = cv2.boxPoints(rotated_rect)
    rect = np.int0(rect)
    return rect

pred_bbox = rect_to_minmax(get_bbox2(iou_grad_cam_image), item['image'])
print("GRAD_CAM2 :",get_iou(pred_bbox, item['objects']['bbox'][0]))
# Out:
# CAM :  0.7799082032505189
# GRAD_CAM : 0.0010820636831974536
# GRAD_CAM2 : 0.5894988230801165

# %% [markdown]
# iou 측정에 사용된 테스트 이미지는 위에서 영역 잘못잡히는 이미지로 테스트 GRAD_CAM의경우 잘못잡는 영역으로 계산했기때문에 많이 떨어짐
# GRAD_CAM2로 영역 맞춰 계산해보면 얼추맞아 떠러지는것 확인

# %% [markdown]
# 회고 : CAM , Grad_CAM, IoU 체크하는 방법에대해서 배웠다 확실히 딥러닝이 학습된걸 눈으로 보고 판단할 수 있으니까 편한것같다 이상 끝.
